# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasuyaPS/EDA_of_Paisabaazar/blob/main/Paisabazaar_Banking_Fraud_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Anasuya P Shivamath

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing customer financial and credit-related data for Paisabazaar to understand the factors associated with different credit-score categories. The dataset contains information related to customers' income, age, banking accounts, credit cards, loans, outstanding debt, credit utilization, payment behavior, delayed payments, credit history, and other financial attributes.
#
# The primary objective of this project is to perform a comprehensive Exploratory Data Analysis (EDA) using the **UBM framework — Univariate, Bivariate, and Multivariate Analysis**. The analysis will identify important patterns, relationships, trends, outliers, and potential risk indicators associated with customer credit scores.
#
# Multiple statistical and visual analysis techniques using **Pandas, NumPy, Matplotlib, Seaborn, and Plotly** will be applied to derive meaningful insights from the data. At least 20 logical and business-relevant visualizations will be developed, with each visualization supported by an explanation of its purpose, key insights, and potential business impact.
#
# The findings from this analysis can help Paisabazaar better understand customer credit behavior, identify factors associated with different levels of creditworthiness, support credit-risk assessment, and contribute to more personalized financial-product recommendations.
#
# The project will also emphasize clean, well-structured, commented, reusable, and error-handled code so that the complete notebook can be executed sequentially without errors.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/AnasuyaPS/EDA_of_Paisabaazar/blob/main/Paisabazaar_Banking_Fraud_Analysis_EDA.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to analyze customer financial and credit-related information and identify meaningful patterns and relationships associated with the customer's **Credit Score**.
#
# The insights obtained from the analysis can help understand customer credit behavior, identify potential risk indicators, and support better credit assessment and personalized financial-product recommendations.

# %% [markdown]
# ### **Business Objectives**
#
# 1. Understand the demographic and financial profile of customers.
# 2. Analyze customer credit and payment behavior.
# 3. Identify factors associated with different credit-score categories.
# 4. Detect unusual values, outliers, and potential data-quality issues.
# 5. Identify relationships between income, debt, credit utilization, payment behavior, and credit score.
# 6. Derive meaningful business insights from the data.
# 7. Provide data-driven observations that can support credit-risk assessment and customer recommendations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# ============================================================
# IMPORT REQUIRED LIBRARIES
# ============================================================

# -----------------------------
# Data Manipulation & Analysis
# -----------------------------
import numpy as np
import pandas as pd


# -----------------------------
# Data Visualization
# -----------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Plotly for interactive visualizations
import plotly.express as px
import plotly.graph_objects as go


# -----------------------------
# Utility & Warning Handling
# -----------------------------
import warnings

# Suppress unnecessary warning messages
# to keep the notebook output clean and readable.
warnings.filterwarnings("ignore")


# ============================================================
# VISUALIZATION CONFIGURATION
# ============================================================

# Set Seaborn theme for consistent and professional charts.
sns.set_theme(style="whitegrid")

# Set default figure size for Matplotlib charts.
plt.rcParams["figure.figsize"] = (10, 6)

# Improve readability of plots.
plt.rcParams["axes.titlesize"] = 14
plt.rcParams["axes.labelsize"] = 11


# ============================================================
# DISPLAY CONFIGURATION
# ============================================================

# Display all columns when viewing DataFrames.
pd.set_option("display.max_columns", None)

# Prevent pandas from unnecessarily shortening wide outputs.
pd.set_option("display.width", 1000)

# Display floating-point values with two decimal places.
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")


# ============================================================
# LIBRARY IMPORT VALIDATION
# ============================================================

print("All required libraries have been imported successfully.")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
data=pd.read_csv('/content/drive/MyDrive/dataset.csv')
data

# %% [markdown]
# ### Dataset First View

# %%
# ============================================================
# DATASET FIRST LOOK
# ============================================================

print("=" * 70)
print("DATASET FIRST LOOK")
print("=" * 70)

# ------------------------------------------------------------
# 1. Display the shape of the dataset
# ------------------------------------------------------------
print("\n1. DATASET SHAPE")
print("-" * 40)

print(f"Number of rows    : {data.shape[0]:,}")
print(f"Number of columns : {data.shape[1]:,}")


# ------------------------------------------------------------
# 2. Display the first 5 records
# ------------------------------------------------------------
print("\n2. FIRST 5 RECORDS")
print("-" * 40)

display(data.head())


# ------------------------------------------------------------
# 3. Display the last 5 records
# ------------------------------------------------------------
print("\n3. LAST 5 RECORDS")
print("-" * 40)

display(data.tail())


# ------------------------------------------------------------
# 4. Display all column names
# ------------------------------------------------------------
print("\n4. COLUMN NAMES")
print("-" * 40)

for number, column in enumerate(data.columns, start=1):
    print(f"{number:02d}. {column}")


# ------------------------------------------------------------
# 5. Display data types
# ------------------------------------------------------------
print("\n5. DATA TYPES")
print("-" * 40)

display(
    data.dtypes
      .to_frame(name="Data_Type")
      .reset_index()
      .rename(columns={"index": "Column"})
)


# ------------------------------------------------------------
# 6. Display basic information about the dataset
# ------------------------------------------------------------
print("\n6. DATASET INFORMATION")
print("-" * 40)

data.info()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# ============================================================
# DATASET ROWS & COLUMNS COUNT
# ============================================================

print("=" * 70)
print("DATASET ROWS & COLUMNS COUNT")
print("=" * 70)

# Get the number of rows and columns
number_of_rows, number_of_columns = data.shape

print(f"\nNumber of Rows    : {number_of_rows:,}")
print(f"Number of Columns : {number_of_columns:,}")

print("\nDataset Shape:")
print(f"({number_of_rows:,}, {number_of_columns:,})")

# %% [markdown]
# ### Dataset Information

# %%
# ============================================================
# DATASET INFORMATION
# ============================================================

print("=" * 70)
print("DATASET INFORMATION")
print("=" * 70)

# Display concise information about the dataset
data.info()

# %% [markdown]
# #### Duplicate Values

# %%
# ============================================================
# DATASET DUPLICATE VALUE COUNT
# ============================================================

print("=" * 70)
print("DATASET DUPLICATE VALUE COUNT")
print("=" * 70)

# Count the number of completely duplicated rows
duplicate_count = data.duplicated().sum()

# Calculate duplicate percentage
duplicate_percentage = (duplicate_count / len(data)) * 100

print(f"\nNumber of duplicate rows    : {duplicate_count:,}")
print(f"Percentage of duplicate rows: {duplicate_percentage:,.2f}%")

if duplicate_count == 0:
    print("\nResult:")
    print("No duplicate rows were found in the dataset.")
else:
    print("\nResult:")
    print(
        f"{duplicate_count:,} duplicate rows ({duplicate_percentage:,.2f}%) "
        "were found in the dataset."
    )
    print("Consider removing them to avoid bias in analysis.")

# %% [markdown]
# #### Missing Values/Null Values

# %%
# ============================================================
# MISSING VALUES / NULL VALUES COUNT
# ============================================================

print("=" * 70)
print("MISSING VALUES / NULL VALUES COUNT")
print("=" * 70)

# Count missing values in each column
missing_count = data.isnull().sum()

# Calculate missing-value percentage
missing_percentage = (missing_count / len(data)) * 100

# Create a summary table
missing_summary = pd.DataFrame({
    "Column": data.columns,
    "Missing_Values": missing_count.values,
    "Missing_Percentage": missing_percentage.values
})

# Sort columns by number of missing values
missing_summary = missing_summary.sort_values(
    by="Missing_Values",
    ascending=False
).reset_index(drop=True)

print("\nMissing Value Summary:")
print("-" * 50)

display(missing_summary)


# ------------------------------------------------------------
# Overall missing-value statistics
# ------------------------------------------------------------

total_missing = missing_count.sum()

print("\nOverall Missing Value Statistics:")
print("-" * 50)
print(f"Total Missing Values : {total_missing:,}")
print(f"Total Rows           : {len(data):,}")
print(f"Total Columns        : {data.shape[1]:,}")


# ------------------------------------------------------------
# Final conclusion
# ------------------------------------------------------------

if total_missing == 0:
    print("\nResult:")
    print("No missing/null values were found in the dataset.")
else:
    columns_with_missing = missing_summary[
        missing_summary["Missing_Values"] > 0
    ]

    print("\nResult:")
    print(
        f"{len(columns_with_missing)} column(s) contain "
        "missing/null values."
    )

# %%
# Visualizing the missing values

# Calculate missing values for each column
missing_values = data.isnull().sum()

# Create the figure
plt.figure(figsize=(14, 6))

# Plot missing values
sns.barplot(
    x=missing_values.index,
    y=missing_values.values
)

# Add chart title and labels
plt.title("Missing Values by Column")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")

# Rotate column names for better readability
plt.xticks(rotation=90)

# Add a horizontal reference line at zero
plt.axhline(
    y=0,
    linewidth=1
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains **100,000 records and 28 columns** related to customers' financial and credit-related information. The main objective is to understand the factors associated with customers' **Credit Score** and use these insights for credit-related analysis.
#
# The dataset includes information about:
#
# * **Customer information:** `Customer_ID`, `Age`, `Occupation`, etc.
# * **Income information:** `Annual_Income`, `Monthly_Inhand_Salary`
# * **Banking information:** `Num_Bank_Accounts`, `Num_Credit_Card`
# * **Loan information:** `Num_of_Loan`, `Type_of_Loan`, `Total_EMI_per_month`
# * **Credit information:** `Interest_Rate`, `Credit_Mix`, `Outstanding_Debt`, `Credit_Utilization_Ratio`
# * **Payment behavior:** `Delay_from_due_date`, `Num_of_Delayed_Payment`, `Payment_of_Min_Amount`, `Payment_Behaviour`
# * **Credit history:** `Credit_History_Age`, `Num_Credit_Inquiries`
# * **Target variable:** `Credit_Score`
#
# From the initial data-quality checks:
#
# * The dataset contains **100,000 rows and 28 columns**.
# * There are **no exact duplicate records**.
# * There are **no missing/null values**.
# * The dataset contains both **numerical and categorical variables**.
# * Multiple records can exist for the same `Customer_ID`, indicating that the dataset contains repeated customer observations, potentially representing different monthly records.
# * `Credit_Score` is the primary target variable for the analysis.
#
# ### Business Understanding
#
# The dataset can help Paisabazaar understand how **income, debt, credit utilization, payment behavior, loan activity, delays, and credit history** are associated with customers' credit scores.
#
# These insights can support areas such as **customer segmentation, personalized financial recommendations, credit-risk assessment, and better targeting of suitable financial products**.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# ============================================================
# DATASET COLUMNS
# ============================================================

print("=" * 70)
print("DATASET COLUMNS")
print("=" * 70)

# Display the total number of columns
print(f"\nTotal Number of Columns: {data.shape[1]}")

print("\nColumn Names:")
print("-" * 50)

# Display each column with its serial number
for number, column in enumerate(data.columns, start=1):
    print(f"{number:02d}. {column}")

# %%
# ============================================================
# DATASET DESCRIBE
# ============================================================

print("=" * 70)
print("DATASET DESCRIPTIVE STATISTICS")
print("=" * 70)

# Generate descriptive statistics for numerical columns
display(data.describe())

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Variables Description
#
# For this section, a **Markdown table** is the cleanest approach. It documents what each variable represents and how it can be useful for the credit-score analysis.
#
# | Variable                     | Description                                                                                                             |
# | ---------------------------- | ----------------------------------------------------------------------------------------------------------------------- |
# | **ID**                       | Unique identifier for each record in the dataset.                                                                       |
# | **Customer_ID**              | Unique identifier associated with a customer. Multiple records may exist for the same customer across different months. |
# | **Month**                    | Month corresponding to the customer's financial/credit record.                                                          |
# | **Name**                     | Name of the customer.                                                                                                   |
# | **Age**                      | Age of the customer in years.                                                                                           |
# | **SSN**                      | Social Security Number or customer identification number associated with the record.                                    |
# | **Occupation**               | Customer's occupation or employment category.                                                                           |
# | **Annual_Income**            | Total annual income of the customer.                                                                                    |
# | **Monthly_Inhand_Salary**    | Monthly salary available to the customer after applicable deductions/adjustments.                                       |
# | **Num_Bank_Accounts**        | Number of bank accounts held by the customer.                                                                           |
# | **Num_Credit_Card**          | Number of credit cards held by the customer.                                                                            |
# | **Interest_Rate**            | Interest rate associated with the customer's credit/loan products.                                                      |
# | **Num_of_Loan**              | Number of loans associated with the customer.                                                                           |
# | **Type_of_Loan**             | Types of loans held by the customer.                                                                                    |
# | **Delay_from_due_date**      | Number of days by which payments were delayed beyond their due date.                                                    |
# | **Num_of_Delayed_Payment**   | Number of delayed payments recorded for the customer.                                                                   |
# | **Changed_Credit_Limit**     | Change in the customer's credit limit.                                                                                  |
# | **Num_Credit_Inquiries**     | Number of credit inquiries made for the customer.                                                                       |
# | **Credit_Mix**               | Category representing the mix/diversity of the customer's credit accounts.                                              |
# | **Outstanding_Debt**         | Total outstanding debt associated with the customer.                                                                    |
# | **Credit_Utilization_Ratio** | Percentage of available credit currently being utilized.                                                                |
# | **Credit_History_Age**       | Length/age of the customer's credit history.                                                                            |
# | **Payment_of_Min_Amount**    | Indicates whether the customer pays the minimum amount due on credit obligations.                                       |
# | **Total_EMI_per_month**      | Total monthly Equated Monthly Installment (EMI) obligation.                                                             |
# | **Amount_invested_monthly**  | Amount invested by the customer on a monthly basis.                                                                     |
# | **Payment_Behaviour**        | Category describing the customer's payment behavior.                                                                    |
# | **Monthly_Balance**          | Average or reported balance maintained by the customer on a monthly basis.                                              |
# | **Credit_Score**             | Target variable representing the customer's credit-score category.                                                      |
#
# ### Business relevance
#
# For this project, variables such as **Annual Income, Outstanding Debt, Credit Utilization Ratio, Delay from Due Date, Number of Delayed Payments, Interest Rate, Credit Mix, Payment Behaviour, and Credit History Age** are particularly important because they can help us understand patterns associated with the customer's `Credit_Score`.
#
# > **Note:** `ID`, `Customer_ID`, `Name`, and `SSN` are primarily identifiers and should generally **not be treated as meaningful predictive features** during modeling. `Customer_ID` is still useful for investigating repeated monthly customer records.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# ============================================================
# CHECK UNIQUE VALUES FOR EACH VARIABLE
# ============================================================

print("=" * 70)
print("UNIQUE VALUES FOR EACH VARIABLE")
print("=" * 70)

# Count the number of unique values in every column
unique_values = data.nunique()

# Create a summary DataFrame
unique_summary = pd.DataFrame({
    "Column": unique_values.index,
    "Unique_Values": unique_values.values
})

# Add the percentage of unique values relative to total records
unique_summary["Unique_Percentage"] = (
    unique_summary["Unique_Values"] / len(data) * 100
).round(2)

# Sort by number of unique values
unique_summary = unique_summary.sort_values(
    by="Unique_Values",
    ascending=False
).reset_index(drop=True)

# Display the result
display(unique_summary)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# ============================================================
# DATA CLEANING & PREPROCESSING
# MAKE DATASET ANALYSIS READY
# ============================================================

print("=" * 70)
print("DATA CLEANING & PREPROCESSING")
print("=" * 70)

# Define the target column
TARGET_COLUMN = 'Credit_Score'

# ------------------------------------------------------------
# 1. Create a copy of the original dataset
# ------------------------------------------------------------
# Keeping the original dataframe unchanged allows us to
# compare the cleaned data with the original data if required.
df_clean = data.copy()

print("\nOriginal dataset copied successfully.")


# ------------------------------------------------------------
# 2. Remove leading/trailing spaces from column names
# ------------------------------------------------------------
# This prevents errors caused by accidental spaces in
# column names during analysis and modeling.
df_clean.columns = df_clean.columns.str.strip()

print("Column names cleaned successfully.")


# ------------------------------------------------------------
# 3. Remove leading/trailing spaces from text columns
# ------------------------------------------------------------
# Text columns may contain unwanted spaces such as
# " Good " instead of "Good".
object_columns = df_clean.select_dtypes(
    include=["object"]
).columns

for column in object_columns:
    df_clean[column] = df_clean[column].str.strip()

print("Text columns cleaned successfully.")


# ------------------------------------------------------------
# 4. Standardize known categorical variables
# ------------------------------------------------------------
# Convert categorical values to a consistent format.
categorical_columns_to_clean = [
    "Occupation",
    "Credit_Mix",
    "Payment_of_Min_Amount",
    "Payment_Behaviour",
    "Credit_Score"
]

for column in categorical_columns_to_clean:
    if column in df_clean.columns:
        df_clean[column] = (
            df_clean[column]
            .astype("string")
            .str.strip()
        )

print("Categorical variables standardized successfully.")


# ------------------------------------------------------------
# 5. Convert numeric columns to numeric data types
# ------------------------------------------------------------
# Some financial columns may be stored as object/string
# because of formatting issues in the raw dataset.
numeric_columns = [
    "Age",
    "Annual_Income",
    "Monthly_Inhand_Salary",
    "Num_Bank_Accounts",
    "Num_Credit_Card",
    "Interest_Rate",
    "Num_of_Loan",
    "Delay_from_due_date",
    "Num_of_Delayed_Payment",
    "Changed_Credit_Limit",
    "Num_Credit_Inquiries",
    "Outstanding_Debt",
    "Credit_Utilization_Ratio",
    "Total_EMI_per_month",
    "Amount_invested_monthly",
    "Monthly_Balance"
]

for column in numeric_columns:
    if column in df_clean.columns:
        # errors="coerce" converts invalid numeric values to NaN
        df_clean[column] = pd.to_numeric(
            df_clean[column],
            errors="coerce"
        )

print("Numeric variables converted successfully.")


# ------------------------------------------------------------
# 6. Convert Month to numeric where applicable
# ------------------------------------------------------------
# Month represents the monthly observation number.
if "Month" in df_clean.columns:
    df_clean["Month"] = pd.to_numeric(
        df_clean["Month"],
        errors="coerce"
    )

print("Month variable processed successfully.")


# ------------------------------------------------------------
# 7. Check and remove exact duplicate records
# ------------------------------------------------------------
# Only exact duplicate rows are removed.
# Repeated Customer_ID values are NOT considered duplicates
# because customers may have multiple monthly observations.
duplicate_count = df_clean.duplicated().sum()

if duplicate_count > 0:
    df_clean = df_clean.drop_duplicates().reset_index(drop=True)
    print(f"Removed {duplicate_count:,} exact duplicate records.")
else:
    print("No exact duplicate records found.")


# ------------------------------------------------------------
# 8. Check missing values created during conversion
# ------------------------------------------------------------
# Numeric conversion may create NaN values if invalid text
# was present in a numeric column.
missing_after_cleaning = df_clean.isnull().sum().sum()

print(
    f"Missing values after cleaning: "
    f"{missing_after_cleaning:,}"
)


# ------------------------------------------------------------
# 9. Check target variable
# ------------------------------------------------------------
# The target variable must be available for the classification
# analysis.
if TARGET_COLUMN not in df_clean.columns:
    raise KeyError(
        f"Target column '{TARGET_COLUMN}' was not found."
    )

print(f"Target variable '{TARGET_COLUMN}' is available.")


# ------------------------------------------------------------
# 10. Remove rows with missing target values, if any
# ------------------------------------------------------------
# Rows without a target value cannot be used for supervised
# classification.
target_missing = df_clean[TARGET_COLUMN].isnull().sum()

if target_missing > 0:
    df_clean = df_clean.dropna(
        subset=[TARGET_COLUMN]
    ).reset_index(drop=True)

    print(
        f"Removed {target_missing:,} rows "
        f"with missing target values."
    )
else:
    print("No missing target values found.")


# ------------------------------------------------------------
# 11. Final dataset summary
# ------------------------------------------------------------
print("\n" + "=" * 70)
print("FINAL DATASET SUMMARY")
print("=" * 70)

print(f"Rows after cleaning    : {df_clean.shape[0]:,}")
print(f"Columns after cleaning : {df_clean.shape[1]:,}")
print(
    f"Missing values         : "
    f"{df_clean.isnull().sum().sum():,}"
)
print(
    f"Duplicate rows         : "
    f"{df_clean.duplicated().sum():,}"
)

print("\nData types:")
display(df_clean.dtypes.to_frame(name="Data_Type"))

print("\nFirst 5 cleaned records:")
display(df_clean.head())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Data Manipulations Performed
#
# The following data-cleaning and preprocessing steps were performed to make the dataset analysis-ready:
#
# 1. **Created a copy of the original dataset** as `df_clean` to preserve the raw data.
# 2. **Cleaned column names** by removing unnecessary leading and trailing spaces.
# 3. **Cleaned text variables** by removing unwanted spaces from categorical/string values.
# 4. **Standardized categorical variables** such as `Occupation`, `Credit_Mix`, `Payment_of_Min_Amount`, `Payment_Behaviour`, and `Credit_Score`.
# 5. **Converted relevant financial and credit-related variables to numeric data types** to enable statistical analysis and visualization.
# 6. **Converted the `Month` variable to numeric format** where applicable.
# 7. **Checked for exact duplicate records** and removed them if present.
# 8. **Checked for missing values after data-type conversion** to ensure that cleaning did not introduce unexpected null values.
# 9. **Validated the target variable `Credit_Score`** to ensure that it is available for further classification analysis.
# 10. **Removed records with missing target values**, if any were identified.
# 11. **Retained identifier columns** such as `ID`, `Customer_ID`, `Name`, and `SSN` for reference and structural analysis, while they can be excluded later from predictive modeling.
#
# ### Insights Found During Data Preparation
#
# * The dataset contains **100,000 records and 28 variables**.
# * The dataset initially contained **no missing/null values**.
# * There were **no exact duplicate records**.
# * The dataset contains both **numerical and categorical variables**.
# * Multiple observations can belong to the same `Customer_ID`, indicating that the data contains **repeated customer-level observations**, potentially across different months.
# * Several variables contain important financial information, including **income, debt, credit utilization, loans, credit inquiries, payment delays, and payment behaviour**.
# * `Credit_Score` is the **target variable** for the subsequent credit-score analysis/classification.
# * Identifier variables such as `ID`, `Name`, and `SSN` are not inherently meaningful financial predictors and should be treated separately from analytical features.
#
# ### Overall Conclusion
#
# The dataset is now **cleaned and analysis-ready**. The preprocessing focused on improving consistency and data types while avoiding unnecessary deletion of valid customer information. The cleaned dataset can now be used for **Univariate, Bivariate, and Multivariate (UBM) analysis**, followed by business insights and credit-score classification.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# ============================================================
# CHART 1: CREDIT SCORE DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

# Count the observations in each credit score category
ax = sns.countplot(
    data=df_clean,
    x="Credit_Score",
    order=df_clean["Credit_Score"].value_counts().index
)

# Add title and axis labels
plt.title("Distribution of Credit Score Categories")
plt.xlabel("Credit Score")
plt.ylabel("Number of Customers")

# Add count labels on top of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I selected a Count Plot (Bar Chart) because `Credit_Score` is a categorical variable.** A count plot is appropriate for comparing how many records belong to each credit-score category.
#
# It helps us quickly understand:
#
# * The **distribution of customers** across credit-score categories.
# * Whether the target classes are **balanced or imbalanced**.
# * Which credit-score category has the **highest and lowest number of records**.
#
# This is important for the Paisabazaar business because the `Credit_Score` variable is our **target variable**, and understanding its distribution is essential before building a classification model.
#
# **Chart type:** Univariate → Categorical → Count Plot / Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### What is/are the insight(s) found from the chart?
#
# * The `Credit_Score` variable contains **three categories: Good, Standard, and Poor**.
# * The chart shows the **number of records/customers in each credit-score category**, making the distribution easy to compare.
# * We can identify whether the dataset is **balanced or imbalanced** across the three categories.
# * If one category has considerably more records than the others, the target variable is **imbalanced**, which should be considered while building the classification model.
# * The distribution also indicates that **different customer credit-risk segments are represented in the dataset**, which is useful for customer segmentation and credit-related analysis.
#
# > **Important:** The exact category with the highest or lowest count should be stated only after looking at the output of your chart. Don't hard-code a category unless your chart confirms it.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The insights from the Credit Score distribution can create positive business impact in the following ways:
#
# * **Better customer segmentation:** Paisabazaar can identify customers as Good, Standard, or Poor credit-score segments and provide more relevant financial products.
# * **Improved credit-risk assessment:** Understanding the target distribution helps in developing a classification model that can identify customers belonging to different credit-risk categories.
# * **Personalized recommendations:** Different credit-score segments can receive suitable recommendations for loans, credit cards, and other financial products.
# * **Better model evaluation:** Knowing whether the target classes are balanced helps select appropriate evaluation metrics and preprocessing techniques.
#
#
#
# **Potentially, yes.** If the chart shows a **significant imbalance between credit-score categories**, it can create a business and modelling risk.
#
# For example, if one category dominates the dataset, a classification model may become biased toward that majority category and perform poorly when identifying customers from smaller categories. This could lead to **incorrect customer segmentation and less suitable financial-product recommendations**.
#
# Therefore, any class imbalance should be addressed during the modelling stage using appropriate techniques such as class weights, resampling, and suitable evaluation metrics such as **precision, recall, F1-score, and confusion matrix**.

# %% [markdown]
# #### Chart - 2

# %%
# ============================================================
# CHART 2: AGE DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="Age",
    bins=30,
    kde=True
)

plt.title("Distribution of Customer Age")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Histogram with a KDE curve** because `Age` is a **numerical variable** and we want to understand how customer ages are distributed.
#
# * A **histogram** groups ages into ranges and shows how frequently customers fall within each range.
# * It helps identify the **most common age groups**.
# * It makes **skewness, spread, and potential outliers** easier to identify.
# * The **KDE curve** provides a smooth view of the overall age distribution.
#
# **UBM Classification:** `Univariate → Numerical → Histogram`

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows the **distribution of customers across different age groups**.
# * Most customers are concentrated within a particular **working-age range**, indicating the dominant age segment in the dataset.
# * The distribution helps identify whether customer age is **normally distributed or skewed** toward younger or older customers.
# * Any unusually low or high age values can be treated as potential **outliers or data-quality issues** and should be investigated.
# * Understanding the dominant age group can help Paisabazaar with **customer segmentation and personalized financial-product recommendations**.
#
# **Key takeaway:** The age distribution provides a clear picture of the customer demographic and can be useful when studying how age relates to **credit behaviour and Credit Score** in later bivariate analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The age distribution can provide useful business insights for Paisabazaar:
#
# * **Customer segmentation:** Identifying the dominant age groups helps understand the primary customer base.
# * **Personalized recommendations:** Financial products and offers can be tailored to the needs of different age groups.
# * **Marketing strategy:** Age-group information can help design more relevant communication and product campaigns.
# * **Credit analysis:** Age can later be compared with `Credit_Score` to determine whether different age groups show different credit-score patterns.
#
#
# The age distribution itself does **not directly indicate negative growth**, but certain data-quality or representation issues could create business risks.
#
# * **Unrealistic age values:** If extremely low or high ages are present, they may represent data-entry errors. Using them without validation could lead to incorrect customer segmentation.
# * **Under-representation of an age group:** If some age groups have very few observations, conclusions about those customers may be unreliable. This could result in less suitable product recommendations for those segments.
# * **Over-reliance on age:** Age alone should not be used to determine a customer's creditworthiness. Financial behaviour, repayment history, debt, credit utilization, and other relevant variables should also be considered.
#
# **Business takeaway:** The chart can support better customer segmentation and personalization, while proper validation prevents demographic insights from leading to inaccurate business decisions.

# %% [markdown]
# #### Chart - 3

# %%
# ============================================================
# CHART 3: ANNUAL INCOME DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="Annual_Income",
    bins=30,
    kde=True
)

plt.title("Distribution of Customer Annual Income")
plt.xlabel("Annual Income")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Histogram with a KDE curve** because `Annual_Income` is a **continuous numerical variable**, and the main objective is to understand how customer income is distributed.
#
# * The **histogram** shows how many customers fall within different income ranges.
# * It helps identify the **most common income ranges** among customers.
# * It reveals the **spread and skewness** of customer income.
# * It can highlight **extremely high or low income values**, which may require further data-quality investigation.
# * The **KDE curve** provides a smooth representation of the overall income distribution.
#
# This chart is useful before analysing relationships between income and variables such as **Outstanding Debt, Credit Utilization, and Credit Score**.
#
# **UBM Classification:** `Univariate → Numerical → Histogram`

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows how **Annual Income is distributed across customers** in the dataset.
# * Most customers are concentrated within a particular **income range**, which represents the dominant income segment of the customer base.
# * The distribution helps identify whether customer income is **symmetric or skewed** toward lower or higher income levels.
# * If a long right tail is visible, it indicates that a relatively small number of customers have **very high annual incomes** compared with the majority.
# * Any extremely high or low income values should be checked as potential **outliers or data-quality issues**.
# * The income distribution provides a useful baseline for later analysing whether **income is associated with Credit Score, Outstanding Debt, and Credit Utilization**.
#
# **Key takeaway:** Customer income varies across a broad range, and understanding this variation is important for analysing customers' financial profiles and developing appropriate credit-product recommendations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The Annual Income distribution can provide useful business insights for Paisabazaar:
#
# * **Customer segmentation:** Customers can be grouped into different income segments for more targeted financial-product recommendations.
# * **Personalized offerings:** Income information can help identify customers who may be suitable for different loan or credit-card products, subject to appropriate credit-risk assessment.
# * **Better credit analysis:** Annual Income can be compared with `Credit_Score`, `Outstanding_Debt`, and `Credit_Utilization_Ratio` to understand broader financial patterns.
# * **Marketing decisions:** Understanding the dominant income segments can help Paisabazaar design more relevant product communication.
#
#
# The chart does not directly indicate negative growth, but **extreme income values or a highly skewed distribution can create business risks**.
#
# * **Extreme income values:** Incorrect income records can distort customer segmentation and lead to unsuitable product recommendations.
# * **Income concentration:** If most customers belong to a narrow income range, conclusions about higher- or lower-income segments may be less reliable because those groups have fewer observations.
# * **Income alone is insufficient:** Using income as the sole basis for credit decisions could lead to inappropriate recommendations. Other factors such as repayment history, debt, credit utilization, and credit score should also be considered.
#
# **Key business takeaway:** Understanding income distribution can support better customer segmentation and personalization, while validating unusual income values and considering multiple financial variables helps reduce the risk of poor business decisions.

# %% [markdown]
# #### Chart - 4

# %%
# ============================================================
# CHART 4: MONTHLY INHAND SALARY DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="Monthly_Inhand_Salary",
    bins=30,
    kde=True
)

plt.title("Distribution of Monthly Inhand Salary")
plt.xlabel("Monthly Inhand Salary")
plt.ylabel("Number of Customers")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Histogram with a KDE curve** because `Monthly_Inhand_Salary` is a **continuous numerical variable**.
#
# * The **histogram** shows how customers are distributed across different monthly salary ranges.
# * It helps identify the **most common salary range** among customers.
# * It makes the **spread and skewness** of salary values easy to understand.
# * It helps detect **extremely high or low salary values**, which may require further investigation as potential outliers.
# * The **KDE curve** provides a smoother view of the overall salary distribution.
#
# This chart is particularly useful for understanding customers' **monthly financial capacity** before studying its relationship with debt, EMI, credit utilization, and `Credit_Score`.
#
# **UBM Classification:** `Univariate → Numerical → Histogram`

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows the **distribution of customers across different monthly in-hand salary ranges**.
# * A large concentration of observations within a particular salary range indicates the **dominant monthly income segment** of the customer base.
# * The shape of the distribution helps identify whether monthly salary is **symmetrical or skewed** toward lower or higher salary levels.
# * A long tail toward higher values would indicate that a **smaller group of customers has substantially higher monthly salaries**.
# * Extremely low or high values can be investigated as **potential outliers or data-quality issues**.
# * The distribution provides a useful foundation for analysing whether **monthly income is associated with debt, EMI, credit utilization, or Credit Score**.
#
# **Key takeaway:** `Monthly_Inhand_Salary` helps us understand customers' monthly financial capacity, which can support more detailed credit-risk and customer-segmentation analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The `Monthly_Inhand_Salary` distribution can provide useful business insights for Paisabazaar:
#
# * **Customer segmentation:** Customers can be grouped into different monthly-income segments.
# * **Personalized product recommendations:** Salary levels can help identify potentially suitable financial products, when considered alongside credit history and other risk factors.
# * **Affordability analysis:** Monthly income can be compared with `Total_EMI_per_month` and `Outstanding_Debt` to understand customers' financial obligations.
# * **Credit-risk analysis:** Combining salary with `Credit_Score` can help identify patterns between income levels and credit profiles.
#
#
#
# The salary distribution itself does **not directly indicate negative growth**, but it can highlight potential business risks:
#
# * **Extreme salary values:** Incorrect or unrealistic values can distort customer segmentation and financial analysis.
# * **Highly concentrated salary distribution:** If most customers fall within a narrow salary range, recommendations based only on salary may not generalize well to other customer segments.
# * **Salary alone is not enough:** A customer with a higher salary may still have substantial debt or poor repayment behaviour. Relying only on salary could therefore result in inappropriate product recommendations.
#
# **Key takeaway:** Monthly in-hand salary is useful for understanding customers' financial capacity, but it should be combined with **debt, EMI, credit utilization, repayment behaviour, and Credit Score** before making business decisions.

# %% [markdown]
# #### Chart - 5

# %%
# ============================================================
# CHART 5: DISTRIBUTION OF OUTSTANDING DEBT
# UBM: Univariate → Numerical
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="Outstanding_Debt",
    bins=30,
    kde=True
)

plt.title("Distribution of Outstanding Debt")
plt.xlabel("Outstanding Debt")
plt.ylabel("Number of Observations")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected a **Histogram with KDE (Kernel Density Estimate)** because `Outstanding_Debt` is a **continuous numerical variable**.
#
# This chart is suitable because it helps us:
#
# * Understand the **distribution of outstanding debt** across observations.
# * Identify the **most common debt range**.
# * Observe the **spread and variation** in debt values.
# * Detect **skewness** in the distribution.
# * Identify potential **extreme values or outliers**.
# * Understand the overall pattern before analyzing how outstanding debt relates to **Credit Score**.
#
# **UBM Classification:**
# **Univariate → Numerical → Histogram**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Outstanding Debt distribution** provides the following insights:
#
# * Most observations are concentrated within a particular **range of outstanding debt**, indicating the common debt level in the dataset.
# * The distribution shows **variation in debt levels** across observations.
# * A **right-skewed pattern** would indicate that most observations have relatively lower debt, while a smaller group carries substantially higher debt.
# * The presence of a **long tail or extreme values** indicates observations with unusually high outstanding debt.
# * These high-debt observations are important because they may indicate **higher financial obligations and potentially greater credit risk**.
# * This chart also provides a baseline for further analysis of the relationship between **Outstanding Debt and Credit Score**.
#
# **Key business insight:** Outstanding debt is an important financial indicator that can be investigated further to understand differences in customers' credit profiles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The insights from the Outstanding Debt distribution can support positive business impact by:
#
# * Helping Paisabazaar identify customers with **higher debt obligations**.
# * Supporting better **credit-risk assessment** and customer segmentation.
# * Enabling more suitable **loan and credit-card recommendations** based on customers' financial profiles.
# * Helping identify customers who may benefit from **debt-management or financial-planning products**.
# * Improving the accuracy of later analysis when Outstanding Debt is combined with **Credit Score, Income, and Credit Utilization**.
#
#
#
# **Yes. A high concentration of customers with very high outstanding debt could create financial and business risks.**
#
# **Specific reasons:**
#
# * High outstanding debt may indicate greater **repayment burden**.
# * Such customers may have a higher likelihood of experiencing **credit-related difficulties**, depending on their other financial characteristics.
# * Offering additional credit without considering existing debt could increase **credit risk and potential losses**.
# * If a large proportion of observations belong to highly indebted customers, successful conversion for additional credit products may be lower.
#
# **Business conclusion:**
# The distribution of Outstanding Debt can help Paisabazaar balance **customer acquisition and product recommendations with responsible credit-risk management**.

# %% [markdown]
# #### Chart - 6

# %%
# ============================================================
# CHART 6: DISTRIBUTION OF CREDIT UTILIZATION RATIO
# UBM: Univariate → Numerical
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df_clean,
    x="Credit_Utilization_Ratio",
    bins=30,
    kde=True
)

plt.title("Distribution of Credit Utilization Ratio")
plt.xlabel("Credit Utilization Ratio")
plt.ylabel("Number of Observations")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected a **Histogram with KDE (Kernel Density Estimate)** because `Credit_Utilization_Ratio` is a **continuous numerical variable**.
#
# This chart is appropriate because it helps us:
#
# * Understand how **credit utilization is distributed** across the observations.
# * Identify the **most common utilization range**.
# * Analyze the **spread and variation** of credit utilization.
# * Detect whether the distribution is **skewed**.
# * Identify potential **extreme values or unusual observations**.
# * Establish a baseline for later analyzing the relationship between **Credit Utilization Ratio and Credit Score**.
#
# **UBM Classification:**
# **Univariate → Numerical → Histogram**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Credit Utilization Ratio distribution** provides the following insights:
#
# * Most observations are concentrated within a **specific range of credit utilization**, showing the commonly observed utilization level.
# * The distribution helps identify whether customers generally maintain **low, moderate, or relatively high credit utilization**.
# * The shape of the distribution indicates the **spread and variation** in credit utilization across observations.
# * A **skewed distribution or long tail** would indicate that a smaller group of observations has unusually high or low utilization.
# * Any extreme values can be investigated as potential **outliers or unusual financial profiles**.
# * Credit utilization is an important variable for further analysis because it can be compared with **Credit Score, Outstanding Debt, and Income** to understand credit-risk patterns.
#
# **Key business insight:**
# Credit utilization provides a useful indicator of how heavily available credit is being used and can therefore contribute to **customer segmentation and credit-risk analysis**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The insights from the Credit Utilization Ratio can create positive business impact by:
#
# * Helping Paisabazaar identify customers with **different levels of credit usage**.
# * Supporting better **credit-risk assessment** when combined with other variables such as Outstanding Debt and Credit Score.
# * Enabling more **personalized credit-card and loan recommendations**.
# * Helping identify customers who may benefit from **financial-planning or credit-management guidance**.
# * Improving customer segmentation and potentially reducing inappropriate credit-product recommendations.
#
#
# **Yes. High credit utilization can indicate a potential financial-risk segment.**
#
# **Specific reasons:**
#
# * Customers with very high credit utilization may have **limited available credit** remaining.
# * High utilization combined with high outstanding debt may indicate a **greater repayment burden**.
# * Recommending additional credit without considering utilization could increase **credit risk and potential repayment problems**.
# * A large high-utilization segment could also reduce successful conversions for some credit products because customers may not meet the desired eligibility criteria.
#
# **Business conclusion:**
# Credit Utilization Ratio can help Paisabazaar balance **personalized product recommendations with responsible credit-risk management**.

# %% [markdown]
# #### Chart - 7

# %%
# ============================================================
# CHART 7: DISTRIBUTION OF PAYMENT BEHAVIOUR
# UBM: Univariate → Categorical
# ============================================================

plt.figure(figsize=(12, 6))

ax = sns.countplot(
    data=df_clean,
    x="Payment_Behaviour",
    order=df_clean["Payment_Behaviour"].value_counts().index
)

plt.title("Distribution of Payment Behaviour")
plt.xlabel("Payment Behaviour")
plt.ylabel("Number of Observations")
plt.xticks(rotation=45, ha="right")

# Display observation counts on each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected a **Count Plot (Bar Chart)** because `Payment_Behaviour` is a **categorical variable**.
#
# This chart is suitable because it helps us:
#
# * Compare the **number of observations in each payment-behaviour category**.
# * Identify the **most common and least common payment behaviours**.
# * Understand how payment behaviour is distributed across the dataset.
# * Detect whether some categories are **under-represented or dominant**.
# * Establish a baseline for later analyzing the relationship between **Payment Behaviour and Credit Score**.
#
# **UBM Classification:**
# **Univariate → Categorical → Count Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Payment Behaviour distribution** provides the following insights:
#
# * The chart shows that **payment behaviour is not evenly distributed** across all categories.
# * Some payment-behaviour categories have **higher representation**, while others have fewer observations.
# * The most frequent category represents the **dominant payment behaviour pattern** in the dataset.
# * The least frequent categories may represent **smaller customer segments** that require separate analysis.
# * Differences in payment behaviour are important because they can be further compared with **Credit Score** to identify whether certain payment patterns are associated with different credit-score categories.
# * The distribution can also help identify **imbalanced categories**, which should be considered when building a classification model.
#
# **Key business insight:**
# Payment behaviour provides a useful basis for **customer segmentation and personalized credit recommendations**, especially when combined with Credit Score and other financial indicators.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes.** The Payment Behaviour insights can create positive business impact by:
#
# * Helping Paisabazaar identify **different customer payment patterns**.
# * Supporting more **personalized loan and credit-card recommendations**.
# * Helping improve **credit-risk assessment** when payment behaviour is analyzed along with Credit Score, debt, and credit utilization.
# * Allowing the business to identify customer segments that may need **financial guidance or credit-management products**.
# * Supporting better customer segmentation, which can improve the relevance of product recommendations.
#
#
#
# **Yes.** If a significant segment shows **unfavorable payment behaviour**, it could create business risks.
#
# **Specific reasons:**
#
# * Poor payment behaviour may indicate a higher **repayment-risk profile**.
# * Recommending additional credit products to such observations without considering other financial factors could increase **credit risk**.
# * Customers with unfavorable payment patterns may have **lower eligibility or lower conversion rates** for certain financial products.
# * If some payment-behaviour categories are heavily under-represented, a classification model may learn those categories poorly, potentially affecting the quality of customer segmentation.
#
# **Business conclusion:**
# Payment Behaviour can help Paisabazaar improve **personalization and risk assessment**, while unfavorable payment patterns should be considered carefully before recommending additional credit products.

# %% [markdown]
# #### Chart - 8

# %%
# ============================================================
# CHART 8: DISTRIBUTION OF CUSTOMER OCCUPATION
# UBM: Univariate → Categorical
# ============================================================

plt.figure(figsize=(12, 6))

ax = sns.countplot(
    data=df_clean,
    x="Occupation",
    order=df_clean["Occupation"].value_counts().index
)

plt.title("Distribution of Customer Occupation")
plt.xlabel("Occupation")
plt.ylabel("Number of Observations")
plt.xticks(rotation=45, ha="right")

# Display observation counts on each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected a **Count Plot (Bar Chart)** because `Occupation` is a **categorical variable**.
#
# This chart is appropriate because it helps us:
#
# * Compare the **number of observations in each occupation category**.
# * Identify the **most common and least common occupations**.
# * Understand the distribution of different occupational groups in the dataset.
# * Detect whether certain occupation categories are **over-represented or under-represented**.
# * Provide a foundation for later analyzing whether **occupation is associated with Credit Score**.
#
# **UBM Classification:**
# **Univariate → Categorical → Count Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Occupation Distribution** chart provides the following insights:
#
# * The number of observations is **not evenly distributed across all occupations**.
# * Some occupations have a **higher representation**, while others have comparatively fewer observations.
# * This indicates that certain occupational groups are more strongly represented in the dataset.
# * The least-represented occupations may provide **less statistical information** for detailed analysis or classification.
# * The chart also helps identify whether the dataset has any **occupation-level imbalance** that should be considered in later Credit Score analysis.
# * This chart provides a useful baseline for the next analysis, where we can examine whether **occupation is associated with differences in Credit Score**.
#
# **UBM Classification:**
# **Univariate → Categorical → Count Plot**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The **Occupation Distribution** insights can support positive business impact in several ways:
#
# * **Customer segmentation:** Paisabazaar can understand which occupational groups are strongly represented and use this information for targeted financial-product recommendations.
# * **Personalized recommendations:** Occupational information, when combined with income, debt, and Credit Score, can help improve personalization of loans, credit cards, and other financial products.
# * **Credit-risk analysis:** Occupation can be analyzed alongside other financial variables to identify patterns associated with different Credit Score categories.
# * **Marketing strategy:** Knowing the representation of different occupations can help optimize campaigns toward relevant customer segments.
# * **Better model development:** Identifying highly and poorly represented occupational groups helps determine whether the classification model may perform differently across segments.
#
#
# Yes, **occupation imbalance can create potential business risks**:
#
# * If some occupations are **underrepresented**, conclusions about those groups may be less reliable.
# * A classification model trained on heavily represented occupations may perform better for those groups and less reliably for smaller groups.
# * If occupation is used too heavily for targeting without considering financial variables such as income, debt, and payment behaviour, customers could receive **less appropriate product recommendations**.
# * If certain occupational groups are associated with higher financial risk, aggressively marketing additional credit to those segments could increase **default or repayment risk**.
#
# **Specific reason:** An imbalanced occupation distribution can cause the business to make decisions based primarily on patterns from larger groups, while smaller groups may receive less accurate risk assessment or personalization. Therefore, occupation should be considered **along with multiple financial indicators**, rather than used as a standalone decision factor.

# %% [markdown]
# #### Chart - 9

# %%
# ============================================================
# CHART 9: ANNUAL INCOME VS OUTSTANDING DEBT
# ============================================================

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_clean,
    x="Annual_Income",
    y="Outstanding_Debt",
    alpha=0.4
)

plt.title("Annual Income vs Outstanding Debt")
plt.xlabel("Annual Income")
plt.ylabel("Outstanding Debt")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a **Scatter Plot** because both `Annual_Income` and `Outstanding_Debt` are **numerical variables**.
#
# A scatter plot is useful because it allows us to:
#
# * Visualize the **relationship between annual income and outstanding debt**.
# * Identify whether there is a **positive, negative, or weak relationship** between the two variables.
# * Observe the **spread and concentration** of observations.
# * Identify **potential outliers**, such as customers with unusually high income or debt.
# * Understand whether customers with different income levels tend to have different debt levels.
#
# **UBM Classification:**
# **Bivariate → Numerical–Numerical → Scatter Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the **Annual Income vs Outstanding Debt** scatter plot, the key insights are:
#
# * The observations show **considerable variation in outstanding debt across different income levels**.
# * There is no clear, perfectly linear relationship visible between annual income and outstanding debt; customers with similar income can have substantially different debt levels.
# * A large concentration of observations appears within particular **income–debt ranges**, representing the common financial profiles in the dataset.
# * Some observations may appear far from the main cluster, indicating **potentially unusual income or debt values** that should be investigated as possible outliers.
# * The chart suggests that **income alone cannot explain a customer's outstanding debt**. Other factors such as number of loans, credit utilization, payment behaviour, and Credit Score should also be considered.
# * This relationship can be explored further by introducing **Credit Score as a third variable**, which can help determine whether different income–debt combinations are associated with different credit-risk profiles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The **Annual Income vs Outstanding Debt** analysis can create positive business impact by helping Paisabazaar better understand customers' financial capacity and existing debt burden.
#
# * **Improved credit-risk assessment:** Comparing income with outstanding debt can help identify customers who may have a relatively high financial burden.
# * **Personalized product recommendations:** Customers can be segmented based on their income and debt profiles before recommending loans or credit cards.
# * **Responsible lending:** High debt relative to income can be considered before suggesting additional borrowing products.
# * **Better financial guidance:** Customers with higher debt burdens can potentially be directed toward suitable debt-management or financial-planning options.
# * **Improved customer targeting:** Combining income and debt with Credit Score can help create more meaningful customer segments.
#
#
#
# Yes. A **high outstanding debt relative to income** can create potential business risks.
#
# **Specific reason:** Customers with substantial existing debt may have greater repayment obligations and therefore may be less suitable for additional credit. If Paisabazaar aggressively recommends new credit products to these customers without considering their existing debt burden, it could increase **repayment risk, potential defaults, and customer financial stress**.
#
# Additionally, if income and debt show a weak relationship, relying on income alone for credit-product recommendations could lead to **inaccurate customer segmentation**.
#
# Therefore, income and outstanding debt should be analyzed together with **Credit Score, credit utilization, delayed payments, and payment behaviour** rather than being used as standalone decision variables.

# %% [markdown]
# #### Chart - 10

# %%
# ============================================================
# CHART 10: CREDIT UTILIZATION RATIO VS OUTSTANDING DEBT
# ============================================================

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_clean,
    x="Credit_Utilization_Ratio",
    y="Outstanding_Debt",
    alpha=0.4
)

plt.title("Credit Utilization Ratio vs Outstanding Debt")
plt.xlabel("Credit Utilization Ratio")
plt.ylabel("Outstanding Debt")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a **Scatter Plot** because both `Credit_Utilization_Ratio` and `Outstanding_Debt` are **numerical variables**.
#
# A scatter plot is suitable because it helps us:
#
# * Examine the **relationship between credit utilization and outstanding debt**.
# * Determine whether higher outstanding debt is associated with higher or lower credit utilization.
# * Identify the **strength and direction of any visible relationship**.
# * Detect **clusters and unusual observations/outliers**.
# * Understand whether customers with high debt also tend to use a larger proportion of their available credit.
#
# This relationship is important for credit-risk analysis because **high credit utilization combined with high outstanding debt may indicate greater financial pressure**.
#
# **UBM Classification:**
# **Bivariate → Numerical–Numerical → Scatter Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the **Credit Utilization Ratio vs Outstanding Debt** scatter plot, the key insights are:
#
# * The chart shows how **credit utilization varies across different levels of outstanding debt**.
# * The observations may show a **weak, moderate, or strong relationship** between the two variables; the overall direction should be judged from the concentration of points rather than assuming a relationship.
# * A large concentration of observations within particular utilization and debt ranges represents the **common financial profiles** in the dataset.
# * Customers with **both relatively high outstanding debt and high credit utilization** deserve closer attention because this combination can indicate a higher existing credit burden.
# * Some observations may lie far from the main cluster, indicating **potential outliers or unusual financial profiles**.
# * The chart also shows why **outstanding debt alone is not sufficient** to understand credit exposure. Credit utilization provides additional information about how much available credit is being used.
# * These insights can be explored further by comparing both variables with **Credit_Score** to determine whether particular debt-utilization combinations are associated with different credit-score categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The **Credit Utilization Ratio vs Outstanding Debt** analysis can provide useful business value for Paisabazaar:
#
# * **Better credit-risk assessment:** Combining utilization and outstanding debt gives a broader view of a customer's existing credit burden.
# * **Personalized recommendations:** Customers with different debt-utilization profiles can receive more appropriate financial-product recommendations.
# * **Responsible credit decisions:** High utilization together with high outstanding debt can be flagged for additional review before recommending further credit.
# * **Improved customer segmentation:** Customers can be grouped based on their overall credit exposure rather than relying on a single financial variable.
# * **Better financial guidance:** Customers showing signs of high credit usage may benefit from debt-management or credit-health guidance.
#
#
#
# Yes. **High outstanding debt combined with high credit utilization** can create a potential business risk.
#
# **Specific reason:** Such customers may already have a significant credit burden and limited available credit. Aggressively recommending additional loans or credit cards to this segment could increase **repayment difficulty, default risk, and customer financial stress**.
#
# There is also a business risk in treating high utilization as an automatic indicator of poor creditworthiness. A customer may have high utilization temporarily while still maintaining good repayment behaviour. Therefore, this insight should be combined with **Credit Score, delayed payments, payment behaviour, income, and other financial indicators** before making customer-level decisions.

# %% [markdown]
# #### Chart - 11

# %%
# ============================================================
# CHART 11: ANNUAL INCOME VS CREDIT UTILIZATION RATIO
# ============================================================

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_clean,
    x="Annual_Income",
    y="Credit_Utilization_Ratio",
    alpha=0.4
)

plt.title("Annual Income vs Credit Utilization Ratio")
plt.xlabel("Annual Income")
plt.ylabel("Credit Utilization Ratio")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a **Scatter Plot** because both `Annual_Income` and `Credit_Utilization_Ratio` are **numerical variables**.
#
# A scatter plot is suitable because it helps us:
#
# * Examine the **relationship between annual income and credit utilization**.
# * Identify whether higher income is associated with **higher or lower credit utilization**.
# * Observe the **distribution and concentration** of observations.
# * Detect **clusters and potential outliers**.
# * Understand whether customers with different income levels tend to use their available credit differently.
#
# This is useful for credit analysis because it helps determine whether **income and credit utilization should be considered together** when assessing a customer's financial profile.
#
# **UBM Classification:**
# **Bivariate → Numerical–Numerical → Scatter Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the **Annual Income vs Credit Utilization Ratio** scatter plot, the key insights are:
#
# * The chart shows that **credit utilization varies across different income levels**.
# * The observations are spread across the plot rather than following a perfectly straight pattern, suggesting that **annual income alone does not fully explain credit utilization**.
# * Customers with similar income levels can have **different credit utilization ratios**, indicating differences in their credit usage and financial behaviour.
# * The chart can reveal **clusters and potential outliers**, such as observations with unusually high utilization relative to their income.
# * High credit utilization at different income levels indicates that **income should not be treated as a standalone indicator of credit health**.
# * Other variables such as **Outstanding Debt, Credit Score, Number of Credit Cards, and Payment Behaviour** should be considered to understand the customer's overall credit profile.
#
# **Business relevance:** This insight supports the idea of combining income with credit-utilization information when performing customer segmentation and credit-risk analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The **Annual Income vs Credit Utilization Ratio** analysis can provide positive business impact for Paisabazaar:
#
# * **Better customer segmentation:** Customers can be grouped based on income and credit-usage patterns.
# * **Improved credit-risk assessment:** Credit utilization can provide additional information beyond income when evaluating a customer's financial profile.
# * **Personalized product recommendations:** Income and utilization together can help determine which financial products may be more appropriate for different customer segments.
# * **Responsible lending:** Customers with high credit utilization can be evaluated more carefully before recommending additional credit.
# * **Better financial guidance:** Customers showing high utilization may benefit from credit-management or debt-management recommendations.
#
#
#
# Yes. **High credit utilization across income groups** can create a potential business risk.
#
# **Specific reason:** A customer may have a relatively high income but still use a large portion of their available credit. If the business relies mainly on income when recommending additional credit products, it could overlook the customer's existing credit burden. This may increase **repayment risk, potential defaults, and customer financial stress**.
#
# At the same time, high utilization should **not automatically be treated as poor credit health**. It should be evaluated together with **Credit Score, Outstanding Debt, delayed payments, payment behaviour, and number of credit accounts**.
#
# Therefore, the key business insight is that **income alone is not sufficient for credit-product recommendations; combining income with credit utilization and other financial indicators can support more informed and responsible decisions.**

# %% [markdown]
# #### Chart - 12

# %%
# ============================================================
# CHART 12: DELAY FROM DUE DATE VS NUMBER OF DELAYED PAYMENTS
# ============================================================
# Scatter plot is used because both variables are numerical.
# It helps us understand whether longer payment delays are
# associated with a higher number of delayed payments.

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df_clean,
    x="Delay_from_due_date",
    y="Num_of_Delayed_Payment",
    alpha=0.4
)

plt.title("Delay from Due Date vs Number of Delayed Payments")
plt.xlabel("Delay from Due Date")
plt.ylabel("Number of Delayed Payments")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Scatter Plot** because both `Delay_from_due_date` and `Num_of_Delayed_Payment` are **numerical variables**. A scatter plot is appropriate for analyzing the relationship between two numerical variables.
#
# It helps us to:
#
# * Identify whether there is a **positive or negative relationship** between payment delay and the number of delayed payments.
# * Understand how the number of delayed payments varies with the **length of payment delay**.
# * Detect **clusters, patterns, and outliers** in payment behavior.
# * Identify observations with both **high delay and many delayed payments**, which may represent higher repayment-risk segments.
#
# **UBM Classification:**
# **Bivariate → Numerical–Numerical → Scatter Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides the following insights:
#
# * There is a **positive relationship** between `Delay_from_due_date` and `Num_of_Delayed_Payment`; observations with longer delays generally tend to have a higher number of delayed payments.
# * Customers with **both high payment delays and a high number of delayed payments** represent a potentially higher-risk repayment segment.
# * The data shows **considerable variation**, meaning the same delay period can be associated with different numbers of delayed payments.
# * Some **outliers** are visible, indicating unusual payment-delay patterns that may require further investigation.
# * The chart suggests that **payment delay behavior is an important indicator of repayment patterns** and should be analyzed together with variables such as `Credit_Score`, `Outstanding_Debt`, and `Credit_Utilization_Ratio`.
#
# **Business insight:** Customers showing repeated and prolonged payment delays may require more careful credit assessment and personalized financial guidance rather than automatic promotion of additional credit products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, the insights can create a positive business impact.**
#
# * **Better credit-risk assessment:** Identifying customers with frequent or prolonged payment delays can help improve credit-score classification.
# * **Personalized financial products:** Customers can be offered credit products that better match their repayment behavior.
# * **Early risk identification:** Customers showing repeated payment delays can be identified for closer monitoring and financial guidance.
# * **Improved customer experience:** Payment reminders and suitable financial recommendations can help customers manage their repayments.
# * **Reduced default risk:** Understanding delayed-payment patterns can support more responsible credit decisions and improve portfolio quality.
#
#
# **Yes.** Customers with **high delay periods and a high number of delayed payments** may represent a higher repayment-risk segment.
#
# **Specific reason:** If additional loans or credit cards are aggressively recommended to customers who are already experiencing repeated payment delays, their financial burden may increase. This could result in higher repayment problems, increased default risk, lower portfolio quality, and ultimately financial losses for the business.
#
# Therefore, the insight should be used for **responsible credit assessment and personalized recommendations**, rather than simply increasing credit-product sales.

# %% [markdown]
# #### Chart - 13

# %%
# ============================================================
# CHART 13: CREDIT SCORE VS ANNUAL INCOME
# ============================================================
# Box plot is used because Annual_Income is numerical and
# Credit_Score is categorical.
# It allows us to compare the income distribution across
# different credit-score categories.

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df_clean,
    x="Credit_Score",
    y="Annual_Income"
)

plt.title("Annual Income Distribution by Credit Score")
plt.xlabel("Credit Score")
plt.ylabel("Annual Income")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Box Plot** because `Annual_Income` is a **numerical variable**, while `Credit_Score` is a **categorical variable**.
#
# A box plot is suitable for comparing the **distribution of annual income across different Credit Score categories**. It helps us clearly identify:
#
# * The **median annual income** for each Credit Score category.
# * The spread and variability of income within each category.
# * Differences in income distributions between Credit Score groups.
# * **Outliers** or unusually high/low income observations.
# * Whether income distributions overlap across Credit Score categories.
#
# **UBM Classification:**
# **Bivariate → Numerical–Categorical → Box Plot**

# %% [markdown]
# :##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides the following insights:
#
# * The **annual income distribution differs across Credit Score categories**, indicating that income may have some relationship with creditworthiness.
# * The **median income** can be compared across the Credit Score groups to identify which groups have relatively higher or lower typical income.
# * There is **considerable overlap** in income distributions between the Credit Score categories, showing that annual income alone does not determine a customer's Credit Score.
# * Some **high-income outliers** are visible, indicating customers with unusually high annual income compared with the majority of observations.
# * The chart suggests that **income should be combined with other financial variables**, such as outstanding debt, credit utilization, delayed payments, and payment behaviour, for better credit-risk analysis.
#
# **Business insight:** Annual income is useful for customer segmentation and credit assessment, but relying on income alone could lead to inaccurate credit decisions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, these insights can create a positive business impact.**
#
# * **Better customer segmentation:** Annual income can help divide customers into different financial segments.
# * **Improved credit assessment:** Income can be considered along with debt, credit utilization, and payment behaviour to understand credit risk.
# * **Personalized recommendations:** Customers can be offered financial products that are more suitable for their income and overall credit profile.
# * **Responsible lending:** Understanding income distribution across Credit Score categories can help reduce unsuitable credit recommendations.
# * **Better financial guidance:** Customers can receive recommendations based on their overall financial capacity.
#
# **Yes.** The major concern is that **annual income alone does not fully explain Credit Score differences**, because the income distributions overlap across Credit Score categories.
#
# **Specific reason:** If Paisabazaar relies heavily on income while recommending loans or credit cards, a high-income customer with **high outstanding debt, high credit utilization, or frequent payment delays** could still be a higher-risk customer. Recommending additional credit based mainly on income could increase repayment risk and potential defaults.
#
# Therefore, **income should be used together with other financial and repayment indicators rather than as a standalone credit-risk measure.**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# ============================================================
# CHART 14: CORRELATION HEATMAP
# ============================================================
# A correlation heatmap is used to visualize the strength and
# direction of relationships between numerical variables.
# This helps identify variables that may be useful for
# further analysis and credit-score classification.

# Select only numerical columns for correlation analysis.
numeric_df = df_clean.select_dtypes(include=["number"])

# Calculate the Pearson correlation matrix.
correlation_matrix = numeric_df.corr()

# Create the heatmap.
plt.figure(figsize=(16, 12))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Variables")
plt.xlabel("Numerical Variables")
plt.ylabel("Numerical Variables")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Correlation Heatmap** because the dataset contains multiple **numerical variables**, and we need to understand how these variables are related to one another.
#
# A correlation heatmap is useful because it:
#
# * Displays the **strength and direction of relationships** between multiple numerical variables at the same time.
# * Uses correlation values ranging from **-1 to +1**, making relationships easy to compare.
# * Helps identify **strong positive and negative correlations**.
# * Helps detect variables that may contain similar or overlapping information.
# * Helps identify potentially important relationships for **Credit Score classification**.
# * Provides a compact overview of the dataset's numerical relationships instead of creating many separate charts.
#
# **UBM Classification:**
# **Multivariate → Numerical–Numerical → Correlation Heatmap**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap provides the following insights:
#
# * It shows the **strength and direction of relationships** between the numerical variables in the dataset.
# * Variables with correlation values closer to **+1** have a strong positive relationship, while values closer to **-1** have a strong negative relationship.
# * Variables with correlation values close to **0** have a relatively weak linear relationship.
# * Some financial variables may show noticeable relationships with each other, helping us understand how factors such as **income, debt, credit utilization, delayed payments, and loan-related variables** interact.
# * The heatmap also helps identify variables that may contain **similar or overlapping information**, which is useful before building a classification model.
# * The relationships identified here can be investigated further using individual bivariate charts to understand their business meaning.
#
# **Important insight:** Correlation shows an **association, not causation**. A strong correlation between two variables does not mean that one variable directly causes the other.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# ============================================================
# CHART 15: PAIR PLOT OF KEY NUMERICAL VARIABLES
# ============================================================
# A pair plot is used to examine relationships between multiple
# numerical variables simultaneously.
#
# A limited set of important variables is selected so that the
# visualization remains readable and computationally efficient.

pairplot_columns = [
    "Annual_Income",
    "Outstanding_Debt",
    "Credit_Utilization_Ratio",
    "Delay_from_due_date",
    "Num_of_Delayed_Payment"
]

# Create a smaller dataframe containing only the selected variables
# and the target variable for visual comparison.
pairplot_df = df_clean[
    pairplot_columns + ["Credit_Score"]
].dropna()

# Create the pair plot.
sns.pairplot(
    pairplot_df,
    vars=pairplot_columns,
    hue="Credit_Score",
    diag_kind="hist",
    plot_kws={"alpha": 0.4}
)

plt.suptitle(
    "Pair Plot of Key Financial Variables by Credit Score",
    y=1.02
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a **Pair Plot** because the analysis involves **multiple numerical variables** and we want to examine their relationships **simultaneously** rather than one pair at a time.
#
# A pair plot is useful because it:
#
# * Shows the relationship between every selected pair of numerical variables.
# * Helps identify **positive, negative, or weak relationships**.
# * Reveals **patterns, clusters, and potential outliers**.
# * Shows the individual distribution of each variable along the diagonal.
# * Uses `Credit_Score` as the `hue`, allowing us to visually compare whether different financial patterns are associated with different credit-score categories.
# * Helps identify which combinations of financial variables may be useful for **credit-score classification**.
#
# **UBM Classification:**
# **Multivariate → Numerical–Numerical with Categorical Hue → Pair Plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The **Pair Plot** provides the following key insights:
#
# * The selected financial variables show **different levels of relationship** with one another; some pairs may show clearer patterns, while others have considerable dispersion.
# * **Annual Income and Outstanding Debt** show how financial obligations vary across different income levels, indicating that income alone does not fully explain a customer's debt position.
# * **Credit Utilization Ratio, Delay from Due Date, and Number of Delayed Payments** provide additional information about repayment and credit-management behaviour.
# * The `Credit_Score` hue helps identify **overlap and separation between credit-score categories** across different financial variables.
# * Observations with combinations such as **higher delays and more delayed payments** can indicate potentially higher repayment-risk segments.
# * **Outliers and unusual observations** are visible in some numerical variables and may require further investigation during data preprocessing.
# * The overall chart suggests that **Credit Score is influenced by a combination of financial characteristics rather than a single variable**.
# * Therefore, for classification, using multiple relevant financial variables together is more informative than relying on only income, debt, or utilization individually.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ## **Solution to Business Objective**
#
# Based on the EDA and credit-score analysis, Paisabazaar can use the identified financial and payment-behaviour patterns to make **more informed, personalized, and responsible credit-related decisions**.
#
# ### Recommended Business Actions
#
# 1. **Develop a Credit Score Classification Model**
#    Use important financial variables such as income, outstanding debt, credit utilization, delayed payments, interest rate, and payment behaviour to classify customers into appropriate credit-score categories.
#
# 2. **Create Risk-Based Customer Segmentation**
#    Segment customers based on their financial profile and credit behaviour rather than relying on a single variable. This can help distinguish customers with different levels of credit risk.
#
# 3. **Personalize Financial Product Recommendations**
#    Recommend suitable loans, credit cards, or other financial products according to the customer's financial capacity, credit profile, and repayment behaviour.
#
# 4. **Identify High-Risk Financial Patterns**
#    Pay particular attention to combinations such as **high outstanding debt, high credit utilization, frequent delayed payments, and longer payment delays**. Such patterns may indicate repayment pressure and should trigger more cautious recommendations.
#
# 5. **Provide Proactive Financial Guidance**
#    Customers showing potentially risky payment patterns can be offered reminders, credit-management guidance, or debt-management information instead of simply promoting additional credit.
#
# 6. **Improve Model Reliability**
#    Monitor class imbalance, outliers, and underrepresented customer groups so that the classification model does not become overly dependent on the largest segments.
#
# ### **Expected Business Impact**
#
# The overall objective is to help Paisabazaar move from **generic product recommendations toward data-driven, risk-aware personalization**. This can support better customer targeting, more responsible credit recommendations, improved risk assessment, and potentially reduce the likelihood of unsuitable credit exposure.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Paisabazaar Banking & Credit Score Analysis provided valuable insights into the financial characteristics and credit behaviour of customers. Through comprehensive **Univariate, Bivariate, and Multivariate (UBM) analysis**, important relationships were identified among income, outstanding debt, credit utilization, payment delays, payment behaviour, and credit score.
#
# The analysis shows that **credit score should not be evaluated using a single financial variable**. A combination of income, debt obligations, credit utilization, delayed payments, and payment behaviour provides a more meaningful understanding of a customer's overall credit profile.
#
# The exploratory analysis also highlighted the importance of identifying **high-risk financial patterns**, such as higher outstanding debt, elevated credit utilization, frequent delayed payments, and longer payment delays. These patterns can help Paisabazaar make more responsible and data-driven credit-related decisions.
#
# Based on these findings, a **Credit Score Classification Model** can be developed to classify customers into appropriate credit-score categories. The model can support customer segmentation, personalized financial-product recommendations, risk assessment, and proactive financial guidance.
#
# Overall, this project demonstrates how **data-driven credit analysis can help Paisabazaar improve personalization and risk-aware decision-making while promoting more suitable financial recommendations for customers**.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
